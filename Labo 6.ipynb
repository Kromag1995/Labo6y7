# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import os

# %%
# %matplotlib notebook

# %%
def binarizacion(picos, mom):
    if mom == "median":
        filtro = np.median(maximos_filtrados_y)
    elif mom == "mean":
        filtro = np.mean(maximos_filtrados_y)
    serie_binaria = []
    for i in picos:
        if i > filtro:
            serie_binaria.append(1)
        else:
            serie_binaria.append(0)
    return serie_binaria, filtro

# %%
carpeta_datos = open("./Muestras sin saturacion/DATA_20190307-0003_4_10Millones.bin", "rb")
a = np.fromfile(carpeta_datos, dtype=np.float)
carpeta_datos.close()

# %%
plt.plot(a[:])
plt.grid()

# %%
filtrados_x = []
filtrados_y = []
for index,dato in enumerate(a):
    if dato == np.inf or dato<0.001:
        pass
    else:
        filtrados_x.append(index)
        filtrados_y.append(dato)

# %%
i_p = 0
f_p = -1
indexs =signal.find_peaks(filtrados_y[i_p:f_p])[0]
maximos_filtrados_y = []
maximos_filtrados_x = []
for i in indexs:
    maximos_filtrados_y.append(filtrados_y[i])
    maximos_filtrados_x.append(filtrados_x[i])

# %%
plt.plot(filtrados_x[:2000],filtrados_y[:2000], '.-')
plt.plot(maximos_filtrados_x[:20],maximos_filtrados_y[:20], 'or')
plt.grid()

# %%
indexs =signal.find_peaks(filtrados_y, height=0.05,distance=15)[0]

# %%
maximos_filtrados_y = []
maximos_filtrados_x = []
for i in indexs:
    maximos_filtrados_y.append(filtrados_y[i])
    maximos_filtrados_x.append(filtrados_x[i])

# %%
i_f, f_f, i_m, f_m = 0,20000, 0,90
plt.plot(filtrados_x[i_f:f_f],filtrados_y[i_f:f_f], '.-')
plt.plot(maximos_filtrados_x[i_m:f_m],maximos_filtrados_y[i_m:f_m], 'or')

# %%
fig, ax = plt.subplots()
ax.stem(maximos_filtrados_x[:100],maximos_filtrados_y[:100])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/gonzalo/Trabajo/Random/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
dif_temporal = []
for i in range(len(maximos_filtrados_x)-1):
    dif_temporal.append(maximos_filtrados_x[i+1]-maximos_filtrados_x[i])

# %%
fig, ax = plt.subplots()
i,f = 450,570
ax.stem(maximos_filtrados_x[i:f],dif_temporal[i:f])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/gonzalo/Trabajo/Random/venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
binario_mean,mean = binarizacion(maximos_filtrados_y, "mean")
binario_median,median = binarizacion(maximos_filtrados_y, "median")
print(mean, median, mean-median)
# Out:
# 0.2118819932104122 0.21259842813014984 -0.0007164349197376352

# %%
mini = 1
for i in a:
    if i>0 and mini>i:
        mini =i
print(mini)
# Out:
# 0.003937007859349251

# %%
for root, dirs, files in os.walk('./datos'):
    print(root,dirs,files)
# Out:
# ./datos ['muestras_del_picoscope_en_bin'] ['muestras_del_picoscope_en_bin.zip']
# ./datos/muestras_del_picoscope_en_bin [] ['DATA_20190307-0004_4_10Millones.bin', 'DATA_20190307-0004_7_10Millones.bin', 'DATA_20190307-0004_1_10Millones.bin', 'DATA_20190307-0004_5_10Millones.bin', 'DATA_20190307-0004_9_10Millones.bin', 'DATA_20190307-0002_3_10Millones.bin', 'DATA_20190307-0002_5_10Millones.bin', 'DATA_20190307-0004_8_10Millones.bin', 'DATA_20190307-0004_6_10Millones.bin', 'DATA_20190307-0002_1_10Millones.bin', 'DATA_20190307-0002_9_10Millones.bin', 'DATA_20190307-0002_8_10Millones.bin', 'DATA_20190307-0002_7_10Millones.bin', 'DATA_20190307-0002_6_10Millones.bin', 'DATA_20190307-0002_2_10Millones.bin', 'DATA_20190307-0004_2_10Millones.bin', 'DATA_20190307-0004_3_10Millones.bin', 'DATA_20190307-0002_4_10Millones.bin']

# %% [markdown]
# <h1>Datos no tan lindos</h1>

# %%
carpeta_datos = open("./datos/muestras_del_picoscope_en_bin/DATA_20190307-0002_1_10Millones.bin", "rb")
a = np.fromfile(carpeta_datos, dtype=np.float)
carpeta_datos.close()

# %%
filtrados_x = []
filtrados_y = []
for index,dato in enumerate(a):
    if dato < 0.001 or dato == np.inf:
        pass
    else:
        filtrados_x.append(index)
        filtrados_y.append(dato)

# %%
i_p = 0
f_p = -1
indexs =signal.find_peaks(filtrados_y[i_p:f_p])[0]
maximos_filtrados_y = []
maximos_filtrados_x = []
for i in indexs:
    maximos_filtrados_y.append(filtrados_y[i])
    maximos_filtrados_x.append(filtrados_x[i])

# %%
plt.plot(filtrados_x[:5000],filtrados_y[:5000], '.-')
plt.plot(maximos_filtrados_x[:50],maximos_filtrados_y[:50], 'or')
plt.grid()

# %%
indexs =signal.find_peaks(filtrados_y, height=0.05,distance=15)[0]
i_p = 0
f_p = -1
maximos_filtrados_y = []
maximos_filtrados_x = []
for i in indexs:
    maximos_filtrados_y.append(filtrados_y[i])
    maximos_filtrados_x.append(filtrados_x[i])

# %%
plt.show()
plt.plot(filtrados_x[:5000],filtrados_y[:5000], '.-')
plt.plot(maximos_filtrados_x[:50],maximos_filtrados_y[:50], 'or')
plt.grid()

# %%
fig, ax = plt.subplots()
ax.stem(maximos_filtrados_x[:100],maximos_filtrados_y[:100])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/gonzalo/Trabajo/Random/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
dif_temporal = []
for i in range(len(maximos_filtrados_x)-1):
    dif_temporal.append(maximos_filtrados_x[i+1]-maximos_filtrados_x[i])

# %%
fig, ax = plt.subplots()
i,f = 0,1000
ax.stem(maximos_filtrados_x[i:f],dif_temporal[i:f])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/gonzalo/Trabajo/Random/venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
